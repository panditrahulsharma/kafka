# %%
import sqlite3
con = sqlite3.connect('telecom.db')
cur = con.cursor()

for row in cur.execute('SELECT * FROM call_dataset_mysql'):
    print(row)
# Out:
# (14178, 13303153919, 'Outgoing', 16, 'gr-0001009643', 'Primary Device', None, 'Primary Device', 'PolycomSoundPointIP-SPIP_450-UA/4.0.2.11532_0004f24181fc', '2019-06-25', '2019-06-25 14:30:22.000000', '2019-06-25 14:31:41.000000', 1.0, '14:00 - 14:59', 'Tuesday')
# (2733, 15127130160, 'Incoming', 16, 'gr-0001011041', 'Primary Device', None, 'Primary Device', 'PolycomVVX-VVX_400-UA/5.4.7.1696_0004f282b3c8', '2019-06-20', '2019-06-20 18:09:21.000000', '2019-06-20 18:21:06.000000', 11.0, '18:00 - 18:59', 'Thursday')
# (11388, 18474633600, 'Outgoing', 16, 'gr-0001007899-2', 'Secondary Device', None, 'Secondary Device', 'PolycomVVX-VVX_500-UA/5.4.7.1696_0004f2aee362', '2019-06-24', '2019-06-24 18:00:01.000000', '2019-06-24 18:29:27.000000', 29.0, '18:00 - 18:59', 'Monday')
# (14967, 16109648000, 'Incoming', 16, 'gr-0001005437', None, None, None, None, '2019-06-25', '2019-06-25 15:40:46.000000', '2019-06-25 15:42:20.000000', 1.0, '15:00 - 15:59', 'Tuesday')
# ...

# %%
(12752,
 16109648000,
 'Outgoing', 
 16,
 'gr-0001005437',
 'Push Notification Retrieval',
 None, None,
 'bc-uc - UC-One (22.6.3 iOS iPhone)',
 '2019-06-24', 
 '2019-06-24 21:43:10.000000', 
 '2019-06-24 21:43:10.000000',
 0.0, '21:00 - 21:59',
 'Monday')

# %%
{
  "INDEXB": 12752,
  "INDEXA": 12752,
  "GROUPS": 16109648000,
  "MISSES_CALL": 16,
  "GROUP_ID": "gr-0001005437",
  "USER_ID": "ndupree@eip.local",
  "USERDEVICETYPE": "bc-uc - UC-One (22.6.3 iOS iPhone)",
  "CALL_DIRECTION": "Outgoing",
  "FEATURES": "Push Notification Retrieval",
  "VPDIALINGFACRESULT": null,
  "USAGEDEVICETYPE": null,
  "DATE_TIME_COLUMN_AM_PM_TIME": "9:43:10",
  "DATE_TIME_COLUMN_START_CALL_TIME": "21:43:10",
  "DATE_TIME_COLUMN_START_CALL_DATE": "2019-06-24",
  "DATE_TIME_COLUMN_END_CALL_TIME": "21:43:10",
  "DATE_TIME_COLUMN_END_CALL_DATE": "2019-06-24",
  "DATE_TIME_COLUMN_WEEKLY_RANGE": "Mon",
  "DATE_TIME_COLUMN_HOURLY_RANGE": "21:00-21:59",
  "DATE_TIME_COLUMN_DURATION": 0,
  "DATE_TIME_COLUMN_START_TIMESTAMP": "2019-06-24T21:43:10.000",
  "DATE_TIME_COLUMN_END_TIMESTAMP": "2019-06-24T21:43:10.000",
  "DATE_TIME_COLUMN_INDEX": 12752
}
